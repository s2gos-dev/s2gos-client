# %% [markdown]
# Before running this notebook, please run
#
# ```bash
# s2gos-server run --service=s2gos.server.services.local.testing:service
# ```

# %%
#import logging
# Configure logging
#logging.basicConfig(level=logging.INFO, force=True)
#logging.getLogger("s2gos").setLevel(logging.DEBUG)

# %%
from s2gos.client.gui import Client
from s2gos.common.models import Execute
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b9f2de4c-ffab-4139-a6f8-37b12e986fe3'>
#   <div id="f7ad431c-688b-4c09-aa89-0ec525b74568" data-root-id="b9f2de4c-ffab-4139-a6f8-37b12e986fe3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
client = Client(debug=True)
client

# %%
client.get_processes()
# Out:
# ProcessList(processes=[ProcessSummary(title='Sleep Processor', description='Sleeps for `duration` seconds. Fails on purpose if `fail` is `True`. Returns the effective amount of sleep in seconds.', keywords=None, metadata=None, additionalParameters=None, id='sleep_a_while', version='0.0.0', jobControlOptions=None, outputTransmission=None, links=None), ProcessSummary(title='Prime Processor', description='Returns the list of prime numbers between a `min_val` and `max_val`. ', keywords=None, metadata=None, additionalParameters=None, id='primes_between', version='0.0.0', jobControlOptions=None, outputTransmission=None, links=None)], links=[])

# %%
client.execute(process_id="sleep_a_while", request=Execute())
client.execute(process_id="sleep_a_while", request=Execute(inputs={"fail": True}))
client.execute(process_id="sleep_a_while", request=Execute(inputs={"duration": 120}))
# Out:
# StatusInfo(processID='sleep_a_while', type=<Type.process: 'process'>, jobID='job_3', status=<StatusCode.accepted: 'accepted'>, message=None, created=datetime.datetime(2025, 6, 19, 8, 48, 40, 812164), started=None, finished=None, updated=None, progress=None, links=None)

# %%
client.show_jobs()
# Out:
# JobsTable(_jobs=[StatusInfo(processID='sleep_a_while', type=<Type.process: 'process'>, jobID='job_32', status=<StatusCode.successful: 'successful'>, message=None, created=datetime.datetime(2025, 6, 19, 8, 46, 31, 246313), started=datetime.datetime(2025, 6, 19, 8, 46, 31, 246625), finished=datetime.datetime(2025, 6, 19, 8, 48, 32, 659514), updated=datetime.datetime(2025, 6, 19, 8, 48, 31, 459390), progress=100, links=None), StatusInfo(processID='sleep_a_while', type=<Type.process: 'process'>, jobID='job_1', status=<StatusCode.running: 'running'>, message=None, created=datetime.datetime(2025, 6, 19, 8, 48, 40, 794319), started=datetime.datetime(2025, 6, 19, 8, 48, 40, 794882), finished=None, updated=datetime.datetime(2025, 6, 19, 8, 48, 40, 794941), progress=0, links=None), StatusInfo(processID='sleep_a_while', type=<Type.process: 'process'>, jobID='job_2', status=<StatusCode.running: 'running'>, message=None, created=datetime.datetime(2025, 6, 19, 8, 48, 40, 805367), started=datetime.
# ...

# %%
#client.stop_updating()
